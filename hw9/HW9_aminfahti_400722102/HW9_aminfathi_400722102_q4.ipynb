# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from google.colab import  files

# %%
uploaded = files.upload()
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a8677a7-0b90-4d98-ac4c-917092f8640d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a8677a7-0b90-4d98-ac4c-917092f8640d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ComputerDepartment.jpg to ComputerDepartment.jpg
#      <input type="file" id="files-ab118962-999d-4eec-8b2d-baef677c2072" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab118962-999d-4eec-8b2d-baef677c2072">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving window.jpg to window.jpg

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img_rgb = cv2.imread('ComputerDepartment.jpg')
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
template = cv2.imread('window.jpg', 0)

height, width = template.shape[::]

res = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)
plt.imshow(res, cmap='gray')

threshold = 0.6039 #For TM_CCOEFF_NORMED, larger values = good fit.

loc = np.where( res >= threshold)  

for pt in zip(*loc[::-1]): 
    cv2.rectangle(img_rgb, pt, (pt[0] + width, pt[1] + height), (0, 255, 0), 1) 

plt.imshow(img_rgb)
cv2.waitKey()
cv2.destroyAllWindows()
